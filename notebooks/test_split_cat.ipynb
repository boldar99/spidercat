# %%
import numpy as np

from spiderstate.well_ordered_cat_state import *
from spidercat.circuit_extraction import CatStateExtractor, StimBuilder

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ns, t = [2,8], 3

graph, forest, roots, dependency_dag, edge = well_ordered_composite_cat_state_data(ns, t, regenerate_graph=True, force_generate=True)

from matplotlib import pyplot as plt
from spidercat.draw import display_digraph, draw_forest_on_graph

print(graph.nodes.data())
draw_forest_on_graph(graph, forest)
plt.show()
display_digraph(dependency_dag)
plt.show()
# Out:
# [(0, {'chunk_idx': 0}), (1, {'is_mark': True, 'chunk_idx': 0}), (2, {'is_mark': True, 'chunk_idx': 0}), (3, {'chunk_idx': 1}), (4, {'chunk_idx': 1}), (5, {'chunk_idx': 1}), (6, {'chunk_idx': 1}), (7, {'chunk_idx': 1}), (8, {'chunk_idx': 1}), (9, {'is_mark': False, 'is_flag': False, 'original_edge': (0, 5), 'chunk_idx': 1}), (10, {'is_mark': True, 'is_flag': False, 'original_edge': (0, 2), 'chunk_idx': 1}), (11, {'is_mark': True, 'is_flag': False, 'original_edge': (0, 1), 'chunk_idx': 1}), (12, {'is_mark': True, 'is_flag': False, 'original_edge': (1, 4), 'chunk_idx': 1}), (13, {'is_mark': True, 'is_flag': False, 'original_edge': (1, 3), 'chunk_idx': 1}), (14, {'is_mark': True, 'is_flag': False, 'original_edge': (2, 3), 'chunk_idx': 1}), (15, {'is_mark': True, 'is_flag': False, 'original_edge': (2, 4), 'chunk_idx': 1}), (16, {'is_mark': True, 'is_flag': False, 'original_edge': (3, 5), 'chunk_idx': 1}), (17, {'is_mark': True, 'is_flag': False, 'original_edge': (4, 5), 'chunk_idx': 1})]

# %%
extractor = CatStateExtractor(StimBuilder(), verbose=False)
circuit = extractor.extract(graph, forest, roots, dependency_dag)
circuit.diagram('timeline-svg')
# Out:
# <svg viewBox="0 0 2464 992"  version="1.1" xmlns="http://www.w3.org/2000/svg">
# <g id="qubit_lines">
# <path id="qubit_line:0" d="M64,64 L2432,64 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="64">q0</text>
# <path id="qubit_line:1" d="M64,128 L2432,128 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="128">q1</text>
# <path id="qubit_line:2" d="M64,192 L2432,192 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="192">q2</text>
# <path id="qubit_line:3" d="M64,256 L2432,256 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="256">q3</text>
# <path id="qubit_line:4" d="M64,320 L2432,320 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="320">q4</text>
# <path id="qubit_line:5" d="M64,384 L2432,384 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="384">q5</text>
# <path id="qubit_line:6" d="M64,448 L2432,448 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="448">q6</text>
# <path id="qubit_line:7" d="M64,512 L2432,512 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="512">q7</text>
# <path id="qubit_line:8" d="M64,576 L2432,576 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="576">q8</text>
# <path id="qubit_line:9" d="M64,640 L2432,640 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="640">q9</text>
# <path id="qubit_line:10" d="M64,704 L2432,704 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="704">q10</text>
# <path id="qubit_line:11" d="M64,768 L2432,768 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="768">q11</text>
# <path id="qubit_line:12" d="M64,832 L2432,832 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="832">q12</text>
# <path id="qubit_line:13" d="M64,896 L2432,896 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="896">q13</text>
# </g>
# <rect x="80" y="48" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="26" x="96" y="64" fill="white">R<tspan baseline-shift="sub" font-size="16">X</tspan></text>
# <rect x="208" y="112" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="224" y="128" fill="white">R</text>
# <path d="M288,64 L288,128 " stroke="black"/>
# <circle cx="288" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="288" cy="128" r="12" stroke="black" fill="white"/>
# <path d="M276,128 L300,128 M288,116 L288,140 " stroke="black"/>
# <path d="M196,40 L196,32 L316,32 L316,40 " stroke="black" fill="none"/>
# <path d="M196,952 L196,960 L316,960 L316,952 " stroke="black" fill="none"/>
# <rect x="336" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="192" fill="white">R</text>
# <path d="M416,64 L416,192 " stroke="black"/>
# <circle cx="416" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="416" cy="192" r="12" stroke="black" fill="white"/>
# <path d="M404,192 L428,192 M416,180 L416,204 " stroke="black"/>
# <path d="M324,40 L324,32 L444,32 L444,40 " stroke="black" fill="none"/>
# <path d="M324,952 L324,960 L444,960 L444,952 " stroke="black" fill="none"/>
# <rect x="464" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="480" y="256" fill="white">R</text>
# <path d="M544,64 L544,256 " stroke="black"/>
# <circle cx="544" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="544" cy="256" r="12" stroke="black" fill="white"/>
# <path d="M532,256 L556,256 M544,244 L544,268 " stroke="black"/>
# <path d="M452,40 L452,32 L572,32 L572,40 " stroke="black" fill="none"/>
# <path d="M452,952 L452,960 L572,960 L572,952 " stroke="black" fill="none"/>
# <rect x="592" y="304" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="608" y="320" fill="white">R</text>
# <path d="M672,256 L672,320 " stroke="black"/>
# <circle cx="672" cy="256" r="12" stroke="none" fill="black"/>
# <circle cx="672" cy="320" r="12" stroke="black" fill="white"/>
# <path d="M660,320 L684,320 M672,308 L672,332 " stroke="black"/>
# <rect x="656" y="368" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="672" y="384" fill="white">R</text>
# <path d="M736,64 L736,384 " stroke="black"/>
# <circle cx="736" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="736" cy="384" r="12" stroke="black" fill="white"/>
# <path d="M724,384 L748,384 M736,372 L736,396 " stroke="black"/>
# <path d="M580,40 L580,32 L764,32 L764,40 " stroke="black" fill="none"/>
# <path d="M580,952 L580,960 L764,960 L764,952 " stroke="black" fill="none"/>
# <rect x="784" y="432" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="800" y="448" fill="white">R</text>
# <path d="M864,320 L864,448 " stroke="black"/>
# <circle cx="864" cy="320" r="12" stroke="none" fill="black"/>
# <circle cx="864" cy="448" r="12" stroke="black" fill="white"/>
# <path d="M852,448 L876,448 M864,436 L864,460 " stroke="black"/>
# <rect x="848" y="496" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="864" y="512" fill="white">R</text>
# <path d="M928,256 L928,512 " stroke="black"/>
# <circle cx="928" cy="256" r="12" stroke="none" fill="black"/>
# <circle cx="928" cy="512" r="12" stroke="black" fill="white"/>
# <path d="M916,512 L940,512 M928,500 L928,524 " stroke="black"/>
# <rect x="912" y="560" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="928" y="576" fill="white">R</text>
# <path d="M992,384 L992,576 " stroke="black"/>
# <circle cx="992" cy="384" r="12" stroke="none" fill="black"/>
# <circle cx="992" cy="576" r="12" stroke="black" fill="white"/>
# <path d="M980,576 L1004,576 M992,564 L992,588 " stroke="black"/>
# <rect x="976" y="624" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="992" y="640" fill="white">R</text>
# <path d="M1056,64 L1056,640 " stroke="black"/>
# <circle cx="1056" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="1056" cy="640" r="12" stroke="black" fill="white"/>
# <path d="M1044,640 L1068,640 M1056,628 L1056,652 " stroke="black"/>
# <path d="M772,40 L772,32 L1084,32 L1084,40 " stroke="black" fill="none"/>
# <path d="M772,952 L772,960 L1084,960 L1084,952 " stroke="black" fill="none"/>
# <rect x="1104" y="688" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1120" y="704" fill="white">R</text>
# <path d="M1184,256 L1184,704 " stroke="black"/>
# <circle cx="1184" cy="256" r="12" stroke="none" fill="black"/>
# <circle cx="1184" cy="704" r="12" stroke="black" fill="white"/>
# <path d="M1172,704 L1196,704 M1184,692 L1184,716 " stroke="black"/>
# <path d="M1092,40 L1092,32 L1212,32 L1212,40 " stroke="black" fill="none"/>
# <path d="M1092,952 L1092,960 L1212,960 L1212,952 " stroke="black" fill="none"/>
# <rect x="1232" y="752" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1248" y="768" fill="white">R</text>
# <path d="M1312,256 L1312,768 " stroke="black"/>
# <circle cx="1312" cy="256" r="12" stroke="none" fill="black"/>
# <circle cx="1312" cy="768" r="12" stroke="black" fill="white"/>
# <path d="M1300,768 L1324,768 M1312,756 L1312,780 " stroke="black"/>
# <path d="M1220,40 L1220,32 L1340,32 L1340,40 " stroke="black" fill="none"/>
# <path d="M1220,952 L1220,960 L1340,960 L1340,952 " stroke="black" fill="none"/>
# <path d="M1376,64 L1376,768 " stroke="black"/>
# <circle cx="1376" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="1376" cy="768" r="12" stroke="black" fill="white"/>
# <path d="M1364,768 L1388,768 M1376,756 L1376,780 " stroke="black"/>
# <rect x="1424" y="752" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1440" y="768" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="1440" y="748">rec[0]</text>
# <path d="M1348,40 L1348,32 L1468,32 L1468,40 " stroke="black" fill="none"/>
# <path d="M1348,952 L1348,960 L1468,960 L1468,952 " stroke="black" fill="none"/>
# <rect x="1488" y="816" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1504" y="832" fill="white">R</text>
# <path d="M1568,64 L1568,832 " stroke="black"/>
# <circle cx="1568" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="1568" cy="832" r="12" stroke="black" fill="white"/>
# <path d="M1556,832 L1580,832 M1568,820 L1568,844 " stroke="black"/>
# <path d="M1476,40 L1476,32 L1596,32 L1596,40 " stroke="black" fill="none"/>
# <path d="M1476,952 L1476,960 L1596,960 L1596,952 " stroke="black" fill="none"/>
# <path d="M1632,320 L1632,832 " stroke="black"/>
# <circle cx="1632" cy="320" r="12" stroke="none" fill="black"/>
# <circle cx="1632" cy="832" r="12" stroke="black" fill="white"/>
# <path d="M1620,832 L1644,832 M1632,820 L1632,844 " stroke="black"/>
# <rect x="1680" y="816" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1696" y="832" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="1696" y="812">rec[1]</text>
# <path d="M1604,40 L1604,32 L1724,32 L1724,40 " stroke="black" fill="none"/>
# <path d="M1604,952 L1604,960 L1724,960 L1724,952 " stroke="black" fill="none"/>
# <rect x="1744" y="880" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1760" y="896" fill="white">R</text>
# <path d="M1824,320 L1824,896 " stroke="black"/>
# <circle cx="1824" cy="320" r="12" stroke="none" fill="black"/>
# <circle cx="1824" cy="896" r="12" stroke="black" fill="white"/>
# <path d="M1812,896 L1836,896 M1824,884 L1824,908 " stroke="black"/>
# <path d="M1732,40 L1732,32 L1852,32 L1852,40 " stroke="black" fill="none"/>
# <path d="M1732,952 L1732,960 L1852,960 L1852,952 " stroke="black" fill="none"/>
# <path d="M1888,384 L1888,896 " stroke="black"/>
# <circle cx="1888" cy="384" r="12" stroke="none" fill="black"/>
# <circle cx="1888" cy="896" r="12" stroke="black" fill="white"/>
# <path d="M1876,896 L1900,896 M1888,884 L1888,908 " stroke="black"/>
# <rect x="1936" y="880" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1952" y="896" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="1952" y="876">rec[2]</text>
# <path d="M1860,40 L1860,32 L1980,32 L1980,40 " stroke="black" fill="none"/>
# <path d="M1860,952 L1860,960 L1980,960 L1980,952 " stroke="black" fill="none"/>
# <path d="M2016,384 L2016,704 " stroke="black"/>
# <circle cx="2016" cy="384" r="12" stroke="none" fill="black"/>
# <circle cx="2016" cy="704" r="12" stroke="black" fill="white"/>
# <path d="M2004,704 L2028,704 M2016,692 L2016,716 " stroke="black"/>
# <rect x="2064" y="688" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="2080" y="704" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2080" y="684">rec[3]</text>
# <rect x="2064" y="752" width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2144" y="768">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2144" y="748">D0 = rec[0]</text>
# <rect x="2064" y="816" width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2144" y="832">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2144" y="812">D1 = rec[1]</text>
# <rect x="2064" y="880" width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2144" y="896">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2144" y="876">D2 = rec[2]</text>
# <rect x="2256" y="688" width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2336" y="704">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2336" y="684">D3 = rec[3]</text>
# <path d="M1988,40 L1988,32 L2428,32 L2428,40 " stroke="black" fill="none"/>
# <path d="M1988,952 L1988,960 L2428,960 L2428,952 " stroke="black" fill="none"/>
# </svg>

# %%
n = 7
def create_balanced_tree(n):
    """
    Constructs a well-balanced binary tree with exactly n leaves using NetworkX.
    """
    G = nx.Graph()
    if n < 1:
        return G
    if n == 1:
        G.add_node(0)
        return G

    # A complete binary tree with 2n - 1 nodes always yields exactly n leaves
    total_nodes = 2 * n - 1
    G.add_nodes_from(range(total_nodes))

    # Internal nodes range from 0 to n-2.
    # Connect each internal node i to its left (2i+1) and right (2i+2) children.
    for i in range(n - 1):
        G.add_edge(i, 2 * i + 1)
        G.add_edge(i, 2 * i + 2)

    return G

nx.draw(create_balanced_tree(n), with_labels=True)
